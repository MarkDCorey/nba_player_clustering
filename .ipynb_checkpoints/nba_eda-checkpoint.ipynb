# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline

# %%
featurized_data = pd.read_csv('~/capstone_project/data/featurized_data.csv')

# %%
featurized_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 562 entries, 0 to 561
# Data columns (total 45 columns):
# Unnamed: 0                   562 non-null int64
# player_id                    562 non-null int64
# display_name                 562 non-null object
# height                       562 non-null int64
# weight                       562 non-null int64
# season_exp                   562 non-null int64
# min_game                     562 non-null float64
# min_tot                      562 non-null float64
# attempt_at_rim_2_min         478 non-null float64
# attempt_cut_run_2_min        478 non-null float64
# attempt_drive_2_min          478 non-null float64
# attempt_jumper_2_min         478 non-null float64
# attempt_jumper_3_min         478 non-null float64
# attempt_off_dribble_2_min    478 non-null float64
# attempt_off_dribble_3_min    478 non-null float64
# attempt_post_2_min           478 non-null float64
# eff_at_rim_2                 460 non-null float64
# eff_cut_run_2                447 non-null float64
# eff_drive_2                  447 non-null float64
# eff_jumper_2                 471 non-null float64
# eff_jumper_3                 432 non-null float64
# eff_off_dribble_2            431 non-null float64
# eff_off_dribble_3            284 non-null float64
# eff_post_2                   410 non-null float64
# ast_min                      478 non-null float64
# blk_min                      478 non-null float64
# blk_a_min                    478 non-null float64
# dreb_min                     478 non-null float64
# oreb_min                     478 non-null float64
# fta_min                      478 non-null float64
# stl_min                      478 non-null float64
# tov_min                      478 non-null float64
# eff_ft                       464 non-null float64
# ast_tov                      472 non-null float64
# c_dreb_min                   478 non-null float64
# c_oreb_min                   478 non-null float64
# d_fga_paint_min              478 non-null float64
# d_fga_perim_min              478 non-null float64
# d_fga_overall_min            478 non-null float64
# d_eff_paint                  468 non-null float64
# d_eff_perim                  470 non-null float64
# d_eff_overall                471 non-null float64
# mi_def_min                   478 non-null float64
# mi_off_min                   478 non-null float64
# pass_min                     478 non-null float64
# dtypes: float64(39), int64(5), object(1)
# memory usage: 197.6+ KB

# %%
featurized_data.min_game.hist()

# %%
data_played = featurized_data[featurized_data.min_tot > 200]

# %%
data_played.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 316 entries, 1 to 500
# Data columns (total 42 columns):
# Unnamed: 0                   316 non-null int64
# player_id                    316 non-null int64
# display_name                 316 non-null object
# height                       316 non-null int64
# weight                       316 non-null int64
# season_exp                   316 non-null int64
# min_game                     316 non-null float64
# attempt_at_rim_2_min         316 non-null float64
# attempt_cut_run_2_min        316 non-null float64
# attempt_drive_2_min          316 non-null float64
# attempt_jumper_2_min         316 non-null float64
# attempt_jumper_3_min         316 non-null float64
# attempt_off_dribble_2_min    316 non-null float64
# attempt_off_dribble_3_min    316 non-null float64
# attempt_post_2_min           316 non-null float64
# eff_at_rim_2                 315 non-null float64
# eff_cut_run_2                315 non-null float64
# eff_drive_2                  315 non-null float64
# eff_jumper_2                 316 non-null float64
# eff_jumper_3                 300 non-null float64
# eff_off_dribble_2            312 non-null float64
# eff_off_dribble_3            233 non-null float64
# eff_post_2                   297 non-null float64
# ast_min                      316 non-null float64
# blk_min                      316 non-null float64
# blk_a_min                    316 non-null float64
# dreb_min                     316 non-null float64
# oreb_min                     316 non-null float64
# fta_min                      316 non-null float64
# stl_min                      316 non-null float64
# tov_min                      316 non-null float64
# eff_ft                       314 non-null float64
# c_dreb_min                   316 non-null float64
# c_oreb_min                   316 non-null float64
# d_fga_paint_min              316 non-null float64
# d_fga_perim_min              316 non-null float64
# d_fga_overall_min            316 non-null float64
# d_eff_paint                  316 non-null float64
# d_eff_perim                  316 non-null float64
# d_eff_overall                316 non-null float64
# mi_def_min                   316 non-null float64
# mi_off_min                   316 non-null float64
# dtypes: float64(36), int64(5), object(1)
# memory usage: 106.2+ KB

# %%
cols = data_played.columns
# for col in data_played.columns:
#     data_played[col].hist()

# %%
columns = data_played.drop(['Unnamed: 0','player_id','display_name'], axis=1).columns
columns = list(columns)

# %%
for col in columns:
    plt.figure()
    plt.title(col)
    data_played[col].hist();

# %%
correlations = data_played[columns].corr()

# %%
correlations.to_csv('~/capstone_project/data/correlations.csv')

# %% [markdown]
# remove age or season_exp
# remove catch and shoot freq (too correlated with attempt jumper 3
# remove both average speed vars - highly correlated with mi_def_min/mi_off_min
# remove either all d_ppm or all d_eff
# remove ast/tov

# %%
from pandas.tools.plotting import scatter_matrix
scatter_matrix(data_played, alpha=0.2, figsize=(6, 6), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x123acf910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1260a8810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x123e6c390>, ...,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1249dce50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1235a8150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12193ff90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x121a8ac90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x123ff0d90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x121957c10>, ...,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1210af990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x127292690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x120097790>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11f433610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ffa7090>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12628bed0>, ...,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x123002e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x123085c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1230f4710>],
#        ...,
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x19ddaf690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x19de1eb90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x19de34fd0>, ...,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a05d8b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a05eded0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a06d5850>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a074e410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a0780b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1005110>, ...,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2e1c090>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2ece8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2f3ed10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a2f7abd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2ffe090>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a31b18d0>, ...,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a57e7d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a5926bd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a59aa090>]], dtype=object)

# %% [markdown]
# #nice visualization of group/cluster counts over a single variable distribution
# #data.groupby('class').plas.hist(alpha=0.4)
#
#
# #histograms for each cluster and variable, good for visualizing distribution of single variable for each cluster separately
# #data.groupby('class').hist()
# #examples: http://3qeqpr26caki16dnhd19sv6by6v.wpengine.netdna-cdn.com/wp-content/uploads/2014/06/histogram_class0.png

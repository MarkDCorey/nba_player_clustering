# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline

# %%
featurized_data = pd.read_csv('~/capstone_project/data/featurized_data.csv')

# %%
featurized_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 562 entries, 0 to 561
# Data columns (total 51 columns):
# Unnamed: 0                   562 non-null int64
# player_id                    562 non-null int64
# display_name                 562 non-null object
# age                          562 non-null int64
# height                       562 non-null int64
# weight                       562 non-null int64
# season_exp                   562 non-null int64
# min_game                     562 non-null float64
# catch_shoot_freq             562 non-null float64
# avg_speed_def                562 non-null float64
# avg_speed_off                562 non-null float64
# d_ppm_overall                562 non-null float64
# d_ppm_paint                  562 non-null float64
# d_ppm_perim                  562 non-null float64
# attempt_at_rim_2_min         478 non-null float64
# attempt_cut_run_2_min        478 non-null float64
# attempt_drive_2_min          478 non-null float64
# attempt_jumper_2_min         478 non-null float64
# attempt_jumper_3_min         478 non-null float64
# attempt_off_dribble_2_min    478 non-null float64
# attempt_off_dribble_3_min    478 non-null float64
# attempt_post_2_min           478 non-null float64
# eff_at_rim_2                 460 non-null float64
# eff_cut_run_2                447 non-null float64
# eff_drive_2                  447 non-null float64
# eff_jumper_2                 471 non-null float64
# eff_jumper_3                 432 non-null float64
# eff_off_dribble_2            431 non-null float64
# eff_off_dribble_3            284 non-null float64
# eff_post_2                   410 non-null float64
# ast_min                      478 non-null float64
# blk_min                      478 non-null float64
# blk_a_min                    478 non-null float64
# dreb_min                     478 non-null float64
# oreb_min                     478 non-null float64
# fta_min                      478 non-null float64
# stl_min                      478 non-null float64
# tov_min                      478 non-null float64
# eff_ft                       464 non-null float64
# ast_tov                      472 non-null float64
# c_dreb_min                   478 non-null float64
# c_oreb_min                   478 non-null float64
# d_fga_paint_min              478 non-null float64
# d_fga_perim_min              478 non-null float64
# d_fga_overall_min            478 non-null float64
# d_eff_paint                  468 non-null float64
# d_eff_perim                  470 non-null float64
# d_eff_overall                471 non-null float64
# mi_def_min                   478 non-null float64
# mi_off_min                   478 non-null float64
# pass_min                     478 non-null float64
# dtypes: float64(44), int64(6), object(1)
# memory usage: 224.0+ KB

# %%
featurized_data.min_game.hist()

# %%
data_played = featurized_data[featurized_data.min_game > 0]

# %%
data_played.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 478 entries, 0 to 500
# Data columns (total 51 columns):
# Unnamed: 0                   478 non-null int64
# player_id                    478 non-null int64
# display_name                 478 non-null object
# age                          478 non-null int64
# height                       478 non-null int64
# weight                       478 non-null int64
# season_exp                   478 non-null int64
# min_game                     478 non-null float64
# catch_shoot_freq             478 non-null float64
# avg_speed_def                478 non-null float64
# avg_speed_off                478 non-null float64
# d_ppm_overall                478 non-null float64
# d_ppm_paint                  478 non-null float64
# d_ppm_perim                  478 non-null float64
# attempt_at_rim_2_min         478 non-null float64
# attempt_cut_run_2_min        478 non-null float64
# attempt_drive_2_min          478 non-null float64
# attempt_jumper_2_min         478 non-null float64
# attempt_jumper_3_min         478 non-null float64
# attempt_off_dribble_2_min    478 non-null float64
# attempt_off_dribble_3_min    478 non-null float64
# attempt_post_2_min           478 non-null float64
# eff_at_rim_2                 460 non-null float64
# eff_cut_run_2                447 non-null float64
# eff_drive_2                  447 non-null float64
# eff_jumper_2                 471 non-null float64
# eff_jumper_3                 432 non-null float64
# eff_off_dribble_2            431 non-null float64
# eff_off_dribble_3            284 non-null float64
# eff_post_2                   410 non-null float64
# ast_min                      478 non-null float64
# blk_min                      478 non-null float64
# blk_a_min                    478 non-null float64
# dreb_min                     478 non-null float64
# oreb_min                     478 non-null float64
# fta_min                      478 non-null float64
# stl_min                      478 non-null float64
# tov_min                      478 non-null float64
# eff_ft                       464 non-null float64
# ast_tov                      472 non-null float64
# c_dreb_min                   478 non-null float64
# c_oreb_min                   478 non-null float64
# d_fga_paint_min              478 non-null float64
# d_fga_perim_min              478 non-null float64
# d_fga_overall_min            478 non-null float64
# d_eff_paint                  468 non-null float64
# d_eff_perim                  470 non-null float64
# d_eff_overall                471 non-null float64
# mi_def_min                   478 non-null float64
# mi_off_min                   478 non-null float64
# pass_min                     478 non-null float64
# dtypes: float64(44), int64(6), object(1)
# memory usage: 194.2+ KB

# %%
cols = data_played.columns
# for col in data_played.columns:
#     data_played[col].hist()

# %%
columns = data_played.drop(['Unnamed: 0','player_id','display_name'], axis=1).columns
columns = list(columns)

# %%
for col in columns:
    plt.figure()
    plt.title(col)
    data_played[col].hist()
# Out:
# age
# height
# weight
# season_exp
# min_game
# catch_shoot_freq
# avg_speed_def
# avg_speed_off
# d_ppm_overall
# d_ppm_paint
# d_ppm_perim
# attempt_at_rim_2_min
# attempt_cut_run_2_min
# attempt_drive_2_min
# attempt_jumper_2_min
# attempt_jumper_3_min
# attempt_off_dribble_2_min
# attempt_off_dribble_3_min
# attempt_post_2_min
# eff_at_rim_2
# eff_cut_run_2
# eff_drive_2
# eff_jumper_2
# eff_jumper_3
# eff_off_dribble_2
# eff_off_dribble_3
# eff_post_2
# ast_min
# blk_min
# blk_a_min
# dreb_min
# oreb_min
# fta_min
# stl_min
# tov_min
# eff_ft
# ast_tov
# c_dreb_min
# c_oreb_min
# d_fga_paint_min
# d_fga_perim_min
# d_fga_overall_min
# d_eff_paint
# d_eff_perim
# d_eff_overall
# mi_def_min
# mi_off_min
# pass_min

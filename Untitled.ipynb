# %%
import pandas as pd
import numpy as np

# %%
feats = pd.read_csv('~/capstone_project/data/featurized_data.csv')
feats.drop(['player_id','gp','min_tot'], inplace = True, axis = 1)

# %%
#use count of corr > .3 to determine whether 
feats.corr()
# Out:
#                           dreb_pos  oreb_pos  attempt_RA_pos  \
# dreb_pos                  1.000000  0.594669        0.212851
# oreb_pos                  0.594669  1.000000        0.379997
# attempt_RA_pos            0.212851  0.379997        1.000000
# attempt_paint_pos         0.249374  0.230279        0.269936
# attempt_corner_3_pos     -0.232030 -0.344479       -0.324267
# attempt_non_corner_3_pos -0.242081 -0.399375       -0.190855
# attempt_mid_pos           0.027569 -0.094033       -0.119055
# ast_pos                  -0.122657 -0.236170        0.015145
# blk_min                   0.319647  0.336010        0.194920
# fta_pos                   0.232873  0.279896        0.363275
# stl_min                  -0.060703 -0.110245        0.015986
# d_fga_paint_pct           0.360452  0.354065        0.229710
# d_fga_perim_pct          -0.298165 -0.280014       -0.182444
# d_fga_threes_pct         -0.343206 -0.434770       -0.276517
# ...

# %%
feats.shape

# %%
import pandas as pd
import numpy as np

# %%
feats = pd.read_csv('~/capstone_project/data/featurized_data.csv')
feats.drop('player_id', inplace = True, axis = 1)

# %%
feats.corr()
# Out:
#                           player_id  dreb_pos        gp  oreb_pos   min_tot  \
# player_id                  1.000000 -0.276550 -0.443996 -0.162066 -0.373725
# dreb_pos                  -0.276550  1.000000  0.659726  0.594669  0.593248
# gp                        -0.443996  0.659726  1.000000  0.344423  0.932204
# oreb_pos                  -0.162066  0.594669  0.344423  1.000000  0.271722
# min_tot                   -0.373725  0.593248  0.932204  0.271722  1.000000
# attempt_RA_pos            -0.023536  0.212851  0.059337  0.379997  0.066156
# attempt_paint_pos         -0.100305  0.249374  0.214205  0.230279  0.221359
# attempt_corner_3_pos      -0.011711 -0.232030  0.007821 -0.344479 -0.004185
# attempt_non_corner_3_pos  -0.040206 -0.242081 -0.007478 -0.399375  0.025747
# attempt_mid_pos           -0.086383  0.027569  0.086201 -0.094033  0.146177
# ast_pos                   -0.133884 -0.122657  0.147426 -0.236170  0.198350
# ...
